# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/requirements.txt) and check software and hardware.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.91 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Training

# %%
# !yolo train data="/content/drive/My Drive/feet_detection/data.yaml" model=yolov8n.pt epochs=200 lr0=0.01
# Out:
# Ultralytics YOLOv8.0.91 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Evaluating

# %%
# !yolo val model='runs/detect/train2/weights/best.pt' data='/content/drive/My Drive/feet_detection/data.yaml'
# Out:
# Ultralytics YOLOv8.0.91 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/My Drive/feet_detection/valid/labels.cache... 106 images, 0 backgrounds, 0 corrupt: 100% 106/106 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 14, len(boxes) = 191. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:04<00:00,  1.54it/s]
#                    all        106        191      0.941       0.88      0.949      0.689
# Speed: 3.9ms preprocess, 6.3ms inference, 0.0ms loss, 5.5ms postprocess per image
# Results saved to runs/detect/val2

# %% [markdown]
# # Predicting

# %%
# !yolo predict model='runs/detect/train2/weights/best.pt' source='/content/drive/My Drive/feet_detection/challenge_data'
# Out:
# Ultralytics YOLOv8.0.91 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/348 /content/drive/My Drive/feet_detection/challenge_data/image_picker_02495D0E-B5A2-4C41-8A6E-CF7F8506CAE4-10685-000006C54A2DEFFF.JPEG: 640x480 1 foot, 78.2ms
# image 2/348 /content/drive/My Drive/feet_detection/challenge_data/image_picker_02DD8296-43FD-44DE-85CA-8FE705594D9D-41429-0000139C7B4DB464.JPEG: 640x480 1 foot, 7.6ms
# image 3/348 /content/drive/My Drive/feet_detection/challenge_data/image_picker_03C58CF5-BBA2-4922-B8ED-561A1AE8A34C-40266-00000D91C6679D0D.JPEG: 640x480 1 foot, 10.3ms
# image 4/348 /content/drive/My Drive/feet_detection/challenge_data/image_picker_03FF891C-7594-4C70-8351-F68035E22BC3-2398-0000012E6F6A8105.JPEG: 480x640 2 foots, 49.3ms
# ...
